# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# df should be converted into dict before we push it to mongodb

data = df.to_dict(orient='records')
#data

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://zaroonjunaidaslam:bbxG0ZndJ3Lq6wpl@cluster0.xqixrwc.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# above, either remove your credentials or delete the mongoDB resource bofore pushing it to github.

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
# Uploading data to MongoDB
rec = collection.insert_many(data)

# %%
# Load back data from mongodb

df = pd.DataFrame(list(collection.find()))
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\pool.py:463, in Connection.receive_message(self, request_id)
#     462 try:
# --> 463     return receive_message(self, request_id, self.max_message_size)
#     464 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\network_layer.py:755, in receive_message(conn, request_id, max_message_size)
#     754 # Ignore the response's request id.
# --> 755 length, _, response_to, op_code = _UNPACK_HEADER(receive_data(conn, 16, deadline))
#     756 # No request_id for exhaust cursor "getMore".
#
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\network_layer.py:360, in receive_data(conn, length, deadline)
#     359     # We reached the true deadline.
# --> 360     raise socket.timeout("timed out") from None
#     361 except socket.timeout:
#
# TimeoutError: timed out
#
# The above exception was the direct cause of the following exception:
#
# NetworkTimeout                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Load back data from mongodb
# ----> 3 df = pd.DataFrame(list(collection.find()))
#       4 df.head(2)
#
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\cursor.py:1284, in Cursor.__next__(self)
#    1283 def __next__(self) -> _DocumentType:
# -> 1284     return self.next()
#
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\cursor.py:1260, in Cursor.next(self)
#    1258 if self._empty:
#    1259     raise StopIteration
# -> 1260 if len(self._data) or self._refresh():
#    1261     return self._data.popleft()
#    1262 else:
#
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\cursor.py:1231, in Cursor._refresh(self)
#    1216     # Exhaust cursors don't send getMore messages.
#    1217     g = self._getmore_class(
#    1218         self._dbname,
#    1219         self._collname,
#    (...)
#    1229         self._comment,
#    1230     )
# -> 1231     self._send_message(g)
#    1233 return len(self._data)
#
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\cursor.py:1102, in Cursor._send_message(self, operation)
#    1099     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1101 try:
# -> 1102     response = client._run_operation(
#    1103         operation, self._unpack_response, address=self._address
#    1104     )
#    1105 except OperationFailure as exc:
#    1106     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1107         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:1896, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1886     operation.reset()  # Reset op in case of retry.
#    1887     return server.run_operation(
#    1888         conn,
#    1889         operation,
#    (...)
#    1893         self,
#    1894     )
# -> 1896 return self._retryable_read(
#    1897     _cmd,
#    1898     operation.read_preference,
#    1899     operation.session,  # type: ignore[arg-type]
#    1900     address=address,
#    1901     retryable=isinstance(operation, _Query),
#    1902     operation=operation.name,
#    1903 )
#
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:2005, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2000 # Ensure that the client supports retrying on reads and there is no session in
#    2001 # transaction, otherwise, we will not support retry behavior for this call.
#    2002 retryable = bool(
#    2003     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2004 )
# -> 2005 return self._retry_internal(
#    2006     func,
#    2007     session,
#    2008     None,
#    2009     operation,
#    2010     is_read=True,
#    2011     address=address,
#    2012     read_pref=read_pref,
#    2013     retryable=retryable,
#    2014     operation_id=operation_id,
#    2015 )
#
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:1972, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1935 @_csot.apply
#    1936 def _retry_internal(
#    1937     self,
#    (...)
#    1946     operation_id: Optional[int] = None,
#    1947 ) -> T:
#    1948     """Internal retryable helper for all client transactions.
#    1949
#    1950     :param func: Callback function we want to retry
#    (...)
#    1959     :return: Output of the calling func()
#    1960     """
#    1961     return _ClientConnectionRetryable(
#    1962         mongo_client=self,
#    1963         func=func,
#    1964         bulk=bulk,
#    1965         operation=operation,
#    1966         is_read=is_read,
#    1967         session=session,
#    1968         read_pref=read_pref,
#    1969         address=address,
#    1970         retryable=retryable,
#    1971         operation_id=operation_id,
# -> 1972     ).run()
#
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:2709, in _ClientConnectionRetryable.run(self)
#    2707 self._check_last_error(check_csot=True)
#    2708 try:
# -> 2709     return self._read() if self._is_read else self._write()
#    2710 except ServerSelectionTimeoutError:
#    2711     # The application may think the write was never attempted
#    2712     # if we raise ServerSelectionTimeoutError on the retry
#    2713     # attempt. Raise the original exception instead.
#    2714     self._check_last_error()
#
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:2870, in _ClientConnectionRetryable._read(self)
#    2862 if self._retrying:
#    2863     _debug_log(
#    2864         _COMMAND_LOGGER,
#    2865         message=f"Retrying read attempt number {self._attempt_number}",
#    (...)
#    2868         operationId=self._operation_id,
#    2869     )
# -> 2870 return self._func(self._session, self._server, conn, read_pref)
#
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:1887, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1880 def _cmd(
#    1881     _session: Optional[ClientSession],
#    1882     server: Server,
#    1883     conn: Connection,
#    1884     read_preference: _ServerMode,
#    1885 ) -> Response:
#    1886     operation.reset()  # Reset op in case of retry.
# -> 1887     return server.run_operation(
#    1888         conn,
#    1889         operation,
#    1890         read_preference,
#    1891         self._event_listeners,
#    1892         unpack_res,
#    1893         self,
#    1894     )
#
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\server.py:208, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res, client)
#     206 else:
#     207     conn.send_message(data, max_doc_size)
# --> 208     reply = conn.receive_message(request_id)
#     210 # Unpack and check for command errors.
#     211 if use_cmd:
#
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\pool.py:466, in Connection.receive_message(self, request_id)
#     464 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     465 except BaseException as error:
# --> 466     self._raise_connection_failure(error)
#
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\synchronous\pool.py:640, in Connection._raise_connection_failure(self, error)
#     638 if isinstance(error, (IOError, OSError, SSLError)):
#     639     details = _get_timeout_details(self.opts)
# --> 640     _raise_connection_failure(self.address, error, timeout_details=details)
#     641 else:
#     642     raise
#
# File c:\Users\M Junaid\anaconda3\envs\vehicle\lib\site-packages\pymongo\pool_shared.py:140, in _raise_connection_failure(address, error, msg_prefix, timeout_details)
#     138     msg += format_timeout_details(timeout_details)
#     139 if isinstance(error, socket.timeout):
# --> 140     raise NetworkTimeout(msg) from error
#     141 elif isinstance(error, SSLError) and "timed out" in str(error):
#     142     # Eventlet does not distinguish TLS network timeouts from other
#     143     # SSLErrors (https://github.com/eventlet/eventlet/issues/692).
#     144     # Luckily, we can work around this limitation because the phrase
#     145     # 'timed out' appears in all the timeout related SSLErrors raised.
#     146     raise NetworkTimeout(msg) from error
#
# NetworkTimeout: ac-4hk6smd-shard-00-01.xqixrwc.mongodb.net:27017: timed out (configured timeouts: connectTimeoutMS: 20000.0ms)
